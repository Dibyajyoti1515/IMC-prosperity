# %%
print("Hello")
# Out:
# Hello

# %%
import pandas as pd

ds1 = pd.read_csv("./Dataset/prices_round_1_day_0.csv", sep=';')
ds1
# Out:
#        day  timestamp               product  bid_price_1  bid_volume_1  \
# 0        0          0     ASH_COATED_OSMIUM          NaN           NaN
# 1        0          0  INTARIAN_PEPPER_ROOT      11991.0          19.0
# 2        0        100  INTARIAN_PEPPER_ROOT      11994.0           9.0
# 3        0        100     ASH_COATED_OSMIUM       9995.0          13.0
# 4        0        200  INTARIAN_PEPPER_ROOT      11991.0          20.0
# ...    ...        ...                   ...          ...           ...
# 19995    0     999700  INTARIAN_PEPPER_ROOT      12989.0          20.0
# 19996    0     999800  INTARIAN_PEPPER_ROOT          NaN           NaN
# 19997    0     999800     ASH_COATED_OSMIUM          NaN           NaN
# 19998    0     999900     ASH_COATED_OSMIUM       9998.0          21.0
# 19999    0     999900  INTARIAN_PEPPER_ROOT      12990.0          23.0
#
#        bid_price_2  bid_volume_2  bid_price_3  bid_volume_3  ask_price_1  \
# ...

# %%
ds1.describe()
# Out:
#            day    timestamp   bid_price_1  bid_volume_1   bid_price_2  \
# count  20000.0   20000.0000  19219.000000  19219.000000  12937.000000
# mean       0.0  499950.0000  11243.526874     12.864977  11239.155136
# std        0.0  288682.3503   1266.278322      5.030537   1268.086183
# min        0.0       0.0000   9976.000000      2.000000   9976.000000
# 25%        0.0  249975.0000   9994.000000     10.000000   9991.000000
# 50%        0.0  499950.0000  11991.000000     12.000000  10004.000000
# 75%        0.0  749925.0000  12492.000000     14.000000  12495.000000
# max        0.0  999900.0000  12993.000000     30.000000  12989.000000
#
#        bid_volume_2   bid_price_3  bid_volume_3   ask_price_1  ask_volume_1  \
# count  12937.000000    433.000000    433.000000  19231.000000  19231.000000
# mean      22.029760  10928.193995     23.346420  11259.546253     12.832978
# std        4.520187   1220.920579      4.003481   1265.821902      4.964625
# ...

# %%
ds1.isnull().sum()
# Out:
# day                    0
# timestamp              0
# product                0
# bid_price_1          781
# bid_volume_1         781
# bid_price_2         7063
# bid_volume_2        7063
# bid_price_3        19567
# bid_volume_3       19567
# ask_price_1          769
# ask_volume_1         769
# ask_price_2         6971
# ask_volume_2        6971
# ask_price_3        19599
# ask_volume_3       19599
# mid_price              0
# profit_and_loss        0
# dtype: int64
